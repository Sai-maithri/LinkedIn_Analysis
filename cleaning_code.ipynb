# %%
import pandas as pd
import os
import re

input_dir = "./LinkedIn Data Public"
output_dir = "./CleanedLinkedInData"

os.makedirs(output_dir, exist_ok=True)

def clean_text(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'[^\w\s,.-]', '', str(text))
    text = ' '.join(text.split())
    return text.strip()

def safe_read_csv(filepath):
    try:
        return pd.read_csv(filepath, encoding='utf-8')
    except UnicodeDecodeError:
        print(f"UTF-8 failed, trying ISO-8859-1 for: {filepath}")
        return pd.read_csv(filepath, encoding='ISO-8859-1')

def standardize_name(name):
    base_name = os.path.splitext(name)[0]
    name_part = base_name.split('-')[-1]
    name_part = re.sub(r'[^A-Za-z\s]', ' ', name_part)
    name_part = ' '.join(word.capitalize() for word in name_part.split())
    
    return f"{name_part}.csv"
for file in os.listdir(input_dir):
    if file.endswith('.csv'):
        input_path = os.path.join(input_dir, file)
        try:
            df = safe_read_csv(input_path)
            df.columns = [col.strip() for col in df.columns]

            required_cols = ['First Name', 'Last Name', 'Company']
            if not all(col in df.columns for col in required_cols):
                print(f"Skipping {file} - missing required columns")
                continue

            df['First Name'] = df['First Name'].apply(clean_text)
            df['Last Name'] = df['Last Name'].apply(clean_text)
            df['Company'] = df['Company'].apply(clean_text)

            cleaned_df = df[required_cols]
            new_name = standardize_name(file)
            output_path = os.path.join(output_dir, new_name)

            cleaned_df.to_csv(output_path, index=False)
            print(f" Saved cleaned file as: {new_name}")

        except Exception as e:
            print(f" Error processing {file}: {str(e)}")
# Out:
#  Saved cleaned file as: Aaditya Raj.csv
#  Saved cleaned file as: Abhishek Singh.csv
#  Saved cleaned file as: Aditya Singh.csv
#  Saved cleaned file as: Afzl Raza.csv
#  Saved cleaned file as: Ajay Jatav.csv
#  Saved cleaned file as: Ajit Yadav.csv
#  Saved cleaned file as: Akanksha.csv
#  Saved cleaned file as: Alok Raj.csv
#  Saved cleaned file as: Aman Adarsh.csv
#  Saved cleaned file as: Aman Singh.csv
#  Saved cleaned file as: Amit Kumar.csv
#  Saved cleaned file as: Anamika Kumari.csv
#  Saved cleaned file as: Anand Pandey.csv
#  Saved cleaned file as: Anoop Kumar.csv
#  Saved cleaned file as: Anshu Kumar.csv
#  Saved cleaned file as: Anuradha Tiwari.csv
#  Saved cleaned file as: Anushri Mishra.csv
#  Saved cleaned file as: Aradhya Patel.csv
#  Saved cleaned file as: Arjun Kadam.csv
#  Saved cleaned file as: Arpita Tripathi.csv
#  Saved cleaned file as: Arun Kumar.csv
#  Saved cleaned file as: Aryan Saini.csv
#  Saved cleaned file as: Ashwin Yadav.csv
#  Saved cleaned file as: Ayush Kumar.csv
#  Saved cleaned file as: Ayush Yadav.csv
#  Saved cleaned file as: Bhagwati Chouhan.csv
#  Saved cleaned file as: Bhaskar Mahato.csv
#  Saved cleaned file as: Byagari Kumar.csv
#  Saved cleaned file as: Challa Trivedh Kumar.csv
#  Saved cleaned file as: Chandan Giri.csv
#  Saved cleaned file as: Chiranjeet Biswas.csv
#  Saved cleaned file as: Vishal Kumar.csv
#  Saved cleaned file as: Aman Adarsh.csv
#  Saved cleaned file as: Aman Verma.csv
#  Saved cleaned file as: Anand Singh.csv
#  Saved cleaned file as: Harshit Chaturvedi.csv
#  Saved cleaned file as: N Arun Kumar.csv
#  Saved cleaned file as: Ompal Yadav.csv
#  Saved cleaned file as: Ravi Rajput.csv
#  Saved cleaned file as: Debangsu Misra.csv
#  Saved cleaned file as: Dilip Suthar.csv
#  Saved cleaned file as: Disha Sahu.csv
#  Saved cleaned file as: Divyanshi Rathour.csv
#  Saved cleaned file as: Divyanshi Sahu.csv
#  Saved cleaned file as: Ekta Kumari.csv
#  Saved cleaned file as: Gaurav Khainwar.csv
#  Saved cleaned file as: Gaurav Tiwari.csv
#  Saved cleaned file as: Harisingh Rajpoot.csv
#  Saved cleaned file as: Himanshu Chundawat.csv
#  Saved cleaned file as: Himanshu Kumar.csv
#  Saved cleaned file as: Himanshu Srivastav.csv
#  Saved cleaned file as: Hiranya Patil.csv
#  Saved cleaned file as: Ishant Bhoyar.csv
#  Saved cleaned file as: Jamal Akhtar.csv
#  Saved cleaned file as: Janu Chaudhary.csv
#  Saved cleaned file as: Karanpal Singh Ranawat.csv
#  Saved cleaned file as: Khushi Narwariya.csv
#  Saved cleaned file as: Kuldeep Saraswat.csv
#  Saved cleaned file as: Lakhan Rathore.csv
#  Saved cleaned file as: Nidhi Kumari.csv
#  Saved cleaned file as: Sneha Shaw.csv
#  Saved cleaned file as: Samina Sultana.csv
#  Saved cleaned file as: Maneesh Sakhwar.csv
#  Saved cleaned file as: Manish Kumar Tiwari.csv
#  Saved cleaned file as: Manoj Kharkar.csv
#  Saved cleaned file as: Manoj Dewda.csv
#  Saved cleaned file as: Mausam Kumari.csv
#  Saved cleaned file as: Mayank Raj.csv
#  Saved cleaned file as: Mehtab Alam.csv
#  Saved cleaned file as: Monis.csv
#  Saved cleaned file as: Mohit Sharma.csv
#  Saved cleaned file as: Monu Rajpoot.csv
#  Saved cleaned file as: Naman Damami.csv
#  Saved cleaned file as: Neeraj Parmar.csv
#  Saved cleaned file as: Nikhil Chaurasiya.csv
#  Saved cleaned file as: Nirmal Mewada.csv
#  Saved cleaned file as: Pawan Kushwah.csv
#  Saved cleaned file as: Pinky Rana.csv
#  Saved cleaned file as: Pooran Singh.csv
#  Saved cleaned file as: Prabhat Patidar.csv
#  Saved cleaned file as: Prachi Dhakad.csv
#  Saved cleaned file as: Pragati Chauhan.csv
#  Saved cleaned file as: Pranjal Dubey.csv
#  Saved cleaned file as: Prem Kumar.csv
#  Saved cleaned file as: Prerana Rajnag.csv
#  Saved cleaned file as: Priyadarshi Kumar.csv
#  Saved cleaned file as: Priya Saini.csv
#  Saved cleaned file as: Pushpraj Singh.csv
#  Saved cleaned file as: Rahul Kumar.csv
#  Saved cleaned file as: Rahul Verma.csv
#  Saved cleaned file as: Rajiv Kumar.csv
#  Saved cleaned file as: Ramraj Nagar.csv
#  Saved cleaned file as: Rani Kumari.csv
#  Saved cleaned file as: Ranjeet Yadav.csv
#  Saved cleaned file as: Ravi Mourya.csv
#  Saved cleaned file as: Ritik Singh.csv
#  Saved cleaned file as: Rohit Kumar.csv
#  Saved cleaned file as: Rohit Malviya.csv
#  Saved cleaned file as: Sajan Kumar.csv
#  Saved cleaned file as: Samina Sultana.csv
#  Saved cleaned file as: Sandeep Kumar.csv
#  Saved cleaned file as: Sandhya Kaushal.csv
#  Saved cleaned file as: Sandhya Parmar.csv
#  Saved cleaned file as: Sarthak Mishra.csv
#  Saved cleaned file as: Satish Mahto.csv
#  Saved cleaned file as: Sauhard Kumar.csv
#  Saved cleaned file as: Saurabh Bisht.csv
#  Saved cleaned file as: Shahid Ansari.csv
#  Saved cleaned file as: Shilpi Shaw.csv
#  Saved cleaned file as: Shivam Shukla.csv
#  Saved cleaned file as: Shivang Dubey.csv
#  Saved cleaned file as: Shlok Gupta.csv
#  Saved cleaned file as: Shubham Kumar.csv
#  Saved cleaned file as: Shubham Kang.csv
#  Saved cleaned file as: Sneha Shaw.csv
#  Saved cleaned file as: Sunny Kumar.csv
#  Saved cleaned file as: Suyash Yadav.csv
#  Saved cleaned file as: Swati Kumari.csv
#  Saved cleaned file as: Ujjval Baijal.csv
#  Saved cleaned file as: Uppara Maithreyi.csv
#  Saved cleaned file as: Vinay Gupta.csv
#  Saved cleaned file as: Vinay Kumar.csv
#  Saved cleaned file as: Vishal Bhardwaj.csv
#  Saved cleaned file as: Vivek Kumar.csv
#  Saved cleaned file as: Vivek Kumar.csv
#  Saved cleaned file as: Yuvraj Bhati.csv
#  Saved cleaned file as: Yuvraj Chirag.csv
